# %% [markdown]
# # **First Notebook**

# %%
print("I am learning python with Dr. Ammar Tufail!")
print("My Name Is Abdul Rehman Shafi")
# Out:
# I am learning python with Dr. Ammar Tufail!
# My Name Is Abdul Rehman Shafi

# %%
print("This is my starting journey to learn python ka chilla with Dr. Ammar Tufail")
print("How are you doing today? My friend")
# Out:
# This is my starting journey to learn python ka chilla with Dr. Ammar Tufail
# How are you doing today? My friend

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # **My Second Line of Code**

# %%
age = 20

# %%
print("My name is Abdul Rehman Shafi and I am", age, "years old")
# Out:
# My name is Abdul Rehman Shafi and I am 20 years old
